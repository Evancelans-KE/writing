# %%
from IPython.display import HTML
import pandas as pd

# %%
dataset = pd.read_csv("nuvi.csv" ,encoding= 'unicode_escape')
dataset
# Out:
#                                      model card slot  \
# 0                                  nüvi 30   microSD
# 1                             nüvi 40/40LM   microSD
# 2                     nüvi 42/42LM/44/44LM   microSD
# 3                             nüvi 50/50LM   microSD
# 4                     nüvi 52/52LM/54/54LM   microSD
# 5                     nüvi 200/250/260/270        SD
# 6                      nüvi 200w/250w/260w        SD
# 7                         nüvi 205/245/255   microSD
# 8                      nüvi 205w/245w/255w        SD
# 9                      nüvi 215T/265T/275T   microSD
# 10                          nüvi 215w/265w        SD
# 11                               nüvi 295w   microSD
# 12                            nüvi 300/350        SD
# 13                        nüvi 310/360/370        SD
# 14                               nuvi 465T        SD
# 15                        nüvi 500/510/550       NaN
# 16                        nüvi 610/660/670        SD
# ...
